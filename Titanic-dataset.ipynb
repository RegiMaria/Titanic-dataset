# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Let's read our data in using pandas

# %%
Titanic = pd.read_csv('titanic.csv')
Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Specify the columns with data relevant to the analysis:

# %%
df_Titanic= Titanic.loc[:, ['Name', 'Age','Sex','Pclass','Survived']]

df_Titanic
# Out:
#                                                   Name   Age     Sex  Pclass  \
# 0                              Braund, Mr. Owen Harris  22.0    male       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female       1
# 2                               Heikkinen, Miss. Laina  26.0  female       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female       1
# 4                             Allen, Mr. William Henry  35.0    male       3
# ..                                                 ...   ...     ...     ...
# 886                              Montvila, Rev. Juozas  27.0    male       2
# 887                       Graham, Miss. Margaret Edith  19.0  female       1
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  female       3
# 889                              Behr, Mr. Karl Howell  26.0    male       1
# 890                                Dooley, Mr. Patrick  32.0    male       3
#
#      Survived
# 0           0
# ...

# %%
#filtered the 'Sex' column for 'female' and the 'Survived' column equal to 1

# %%
df_female_survivors = df_Titanic[(df_Titanic['Survived'] == 1) & (df_Titanic['Sex'] == 'female')]
df_female_survivors
# Out:
#                                                   Name   Age     Sex  Pclass  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female       1
# 2                               Heikkinen, Miss. Laina  26.0  female       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female       1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female       3
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0  female       2
# ..                                                 ...   ...     ...     ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  28.0  female       2
# 875                   Najib, Miss. Adele Kiamie "Jane"  15.0  female       3
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0  female       1
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  25.0  female       2
# 887                       Graham, Miss. Margaret Edith  19.0  female       1
#
#      Survived
# 1           1
# ...

# %%
#Survivors by class:

# %%
survivors_by_class= df_female_survivors.groupby('Pclass')['Survived'].sum()
survivors_by_class
# Out:
# Pclass
# 1    91
# 2    70
# 3    72
# Name: Survived, dtype: int64

# %%
#Let's take a Look at our data graphically:

# %%
plt.title('Female Survivors by class')
survivors_by_class = df_female_survivors[df_female_survivors['Survived'] == 1]['Pclass'].value_counts().sort_values()
plt.bar(survivors_by_class.index, survivors_by_class.values, color='blue')
plt.xticks([1,2,3])
plt.xlabel('Class group')
plt.ylabel('Numbers of Survivors')
plt.savefig('df_female_survivors.png')

# %%
df_female_survivors.to_excel('df_female_survivors.xlsx', index = False)

# %%
df_female_survivors.to_csv('df_female_survivors.csv', index = False)
